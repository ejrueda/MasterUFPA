# %% [markdown]
# <center> <h1> Essential genes obtained from DEG database (http://www.essentialgene.org/)</h1>
#
# <b>Autor:</b> Edwin Rueda <br>
# <b>email:</b> ejrueda95g@gmail.com <br>
# <b>github:</b> https://github.com/ejrueda <br>
# <b>website:</b> http://edwinrueda.com/ <br>
# <b> You can cite this work with</b>:
#
# @software{edwin_rueda_2020_3843381,<br>
#   author       = {Edwin Rueda},<br>
#   title        = {ejrueda/MasterUFPA: zenodo release},<br>
#   month        = may,<br>
#   year         = 2020,<br>
#   publisher    = {Zenodo},<br>
#   version      = {zenodo},<br>
#   doi          = {10.5281/zenodo.3843381},<br>
#   url          = {https://doi.org/10.5281/zenodo.3843381}<br>
# }

# %%
import pandas as pd
import numpy as np

# %%
data_essential_genes = pd.read_csv("../data/DEG_essential_genes_escherichia_coli_MG1655I.csv")
e_genes = data_essential_genes[" Gene Name"].values
data_essential_genes.head()
# Out:
#    No                       DEG ID             Gene Name  \
# 0   1                  DEG10180001                   mog
# 1   2                  DEG10180002                  dnaK
# 2   3                  DEG10180003                  insA
# 3   4                  DEG10180004                  rpsT
# 4   5                  DEG10180005                  ribF
#
#                                             Function  \
# 0                  Molybdopterin biosynthesis mog...
# 1                             Chaperone protein dnaK
# 2                  Insertion element IS1 1/2/3/5/...
# 3                          30S ribosomal protein S20
# 4                  Riboflavin biosynthesis protei...
#
#                                     Organism
# 0                  Escherichia coli MG1655 I
# 1                  Escherichia coli MG1655 I
# 2                  Escherichia coli MG1655 I
# 3                  Escherichia coli MG1655 I
# 4                  Escherichia coli MG1655 I

# %%
ess_genes = []
for g in e_genes:
    for k in g.strip().split("/"):
        ess_genes.append(k)

# %%
len(np.unique(ess_genes))
# Out:
# 66

# %%
candidates = pd.read_csv("../data/ICCSA_cantidates_06_03_20_v1.csv", index_col=0)
print("number of candidate genes:", len(candidates.index.unique()))
print(candidates.shape)
candidates.head()
# Out:
# number of candidate genes: 807
# (807, 9)
#            BB9      BB10      BB17      BB19      BB20      BB21      BB11  \
# gene
# aaeA -1.021960 -0.979435 -1.070980 -0.936075 -0.964250 -1.031994 -0.934337
# aas  -0.922192 -0.918634 -0.912901 -0.955073 -0.996782 -0.974946 -0.973578
# accB -0.514109  0.918962  1.020704  0.785425  0.781750  0.679621  0.702075
# aceB  0.857671  0.777676  0.822172  0.077504  0.069610 -0.091237 -0.130144
# aceE  0.966515  0.934333  1.030230  0.849922  0.855701  0.749005  0.780537
#
#           BB12      BB18
# gene
# aaeA -0.939543 -0.937269
# aas  -0.897515 -0.892211
# accB  0.594880  0.713118
# aceB  1.031624 -0.112132
# aceE  0.621839  0.832078

# %%
new_candidates = candidates.reindex(ess_genes).dropna()
new_candidates
# Out:
#            BB9      BB10      BB17      BB19      BB20      BB21      BB11  \
# gene
# mog   0.656634  0.623242  0.695255  0.674127  0.633453  0.641202  0.567436
# rpsT  0.032127  0.042489  0.186805  0.085710  0.050350 -0.065027 -0.044955
# ileS  0.722778  0.683867  0.766918  0.752271  0.744708  0.666272  0.613139
# lptD  0.814114  0.805638  0.876417  0.896848  0.891923  0.807026 -0.747148
# rsmH  0.689306  0.673681  0.738644  0.738341  0.722884  0.695303  0.607246
# ...        ...       ...       ...       ...       ...       ...       ...
# mtn   0.740601  0.707709  0.771822  0.694781  0.704438  0.648599  0.593613
# rpsB  0.974112  0.962463 -0.345633  1.040985  1.020971  0.937597  0.805798
# frr   0.682423  0.642858  0.674951  0.796379  0.746249  0.699122  0.667187
# lpxB -0.951299 -0.970790 -0.943220 -0.951399 -0.958310 -1.051191 -1.019990
# dnaE -0.943993 -0.967200 -0.895392 -0.945880 -0.985317 -1.034085 -1.025809
#
#           BB12      BB18
# gene
# mog  -0.918164  0.565987
# rpsT -0.319807 -0.105564
# ileS  0.538954  0.640299
# lptD  0.570029  0.704011
# rsmH -0.902356  0.618859
# ...        ...       ...
# mtn   0.528070  0.608835
# rpsB  0.620596  0.800866
# frr  -0.921096  0.650343
# lpxB -1.011627 -0.966712
# dnaE -1.010013 -0.965427
#
# [176 rows x 9 columns]

# %%
new_candidates.loc["mog"]
# Out:
#            BB9      BB10      BB17      BB19      BB20      BB21      BB11  \
# gene
# mog   0.656634  0.623242  0.695255  0.674127  0.633453  0.641202  0.567436
# mog   0.656634  0.623242  0.695255  0.674127  0.633453  0.641202  0.567436
# mog   0.656634  0.623242  0.695255  0.674127  0.633453  0.641202  0.567436
# mog   0.656634  0.623242  0.695255  0.674127  0.633453  0.641202  0.567436
# mog   0.656634  0.623242  0.695255  0.674127  0.633453  0.641202  0.567436
# mog   0.656634  0.623242  0.695255  0.674127  0.633453  0.641202  0.567436
# mog   0.656634  0.623242  0.695255  0.674127  0.633453  0.641202  0.567436
# mog   0.656634  0.623242  0.695255  0.674127  0.633453  0.641202  0.567436
# mog   0.656634  0.623242  0.695255  0.674127  0.633453  0.641202  0.567436
# mog   0.656634  0.623242  0.695255  0.674127  0.633453  0.641202  0.567436
# mog   0.656634  0.623242  0.695255  0.674127  0.633453  0.641202  0.567436
#
#           BB12      BB18
# gene
# mog  -0.918164  0.565987
# mog  -0.918164  0.565987
# mog  -0.918164  0.565987
# mog  -0.918164  0.565987
# mog  -0.918164  0.565987
# mog  -0.918164  0.565987
# mog  -0.918164  0.565987
# mog  -0.918164  0.565987
# mog  -0.918164  0.565987
# mog  -0.918164  0.565987
# mog  -0.918164  0.565987

# %%
artigo_moose = pd.read_csv("../data/RG_artigoMoose.txt", names=["genes"])
artigo_moose
# Out:
#    genes
# 0   dnaG
# 1   dtpB
# 2   ftsX
# 3   ftsY
# 4   glyY
# 5   gyrB
# 6    lhr
# 7   mutM
# 8   mutY
# 9    ndk
# 10  nfuA
# 11   pnp
# 12  rbbA
# 13  rhsB
# 14  rpsU
# 15  rrsE
# 16  rrsG
# 17  secB
# 18  spoT
# 19  tfaR
# 20  thrW
# 21  valS
# 22  yedJ
# 23  ynaE
# 24  yphG
# 25  zntA
# 26  zupT

# %%
a.reindex(artigo_moose.genes).dropna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-5c3ac830d422> in <module>
# ----> 1 a.reindex(artigo_moose.genes).dropna()
#
# ~/.local/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     219         @wraps(func)
#     220         def wrapper(*args, **kwargs):
# --> 221             return func(*args, **kwargs)
#     222
#     223         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    3959         kwargs.pop("axis", None)
#    3960         kwargs.pop("labels", None)
# -> 3961         return super().reindex(**kwargs)
#    3962
#    3963     def drop(
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4512         # perform the reindex on the axes
#    4513         return self._reindex_axes(
# -> 4514             axes, level, limit, tolerance, method, fill_value, copy
#    4515         ).__finalize__(self)
#    4516
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3847         if index is not None:
#    3848             frame = frame._reindex_index(
# -> 3849                 index, method, copy, level, fill_value, limit, tolerance
#    3850             )
#    3851
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    3869             copy=copy,
#    3870             fill_value=fill_value,
# -> 3871             allow_dups=False,
#    3872         )
#    3873
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4575                 fill_value=fill_value,
#    4576                 allow_dups=allow_dups,
# -> 4577                 copy=copy,
#    4578             )
#    4579
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1249         # some axes don't allow reindexing with dups
#    1250         if not allow_dups:
# -> 1251             self.axes[axis]._can_reindex(indexer)
#    1252
#    1253         if axis >= self.ndim:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in _can_reindex(self, indexer)
#    3360         # trying to reindex on an axis with duplicates
#    3361         if not self.is_unique and len(indexer):
# -> 3362             raise ValueError("cannot reindex from a duplicate axis")
#    3363
#    3364     def reindex(self, target, method=None, level=None, limit=None, tolerance=None):
#
# ValueError: cannot reindex from a duplicate axis
