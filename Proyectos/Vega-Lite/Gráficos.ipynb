# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import bokeh.plotting as bp
from bokeh.layouts import gridplot
# %matplotlib inline

# %% [markdown]
# #### Gráfico 1

# %%
fig = plt.figure(figsize=(6,4))
plt.title("Chuva acumulada por período no mês de Maio", size=14)
x = range(3)
y = [28.7,1.6,49.8]
plt.axes().spines['right'].set_visible(False)
plt.axes().spines['top'].set_visible(False)
#plt.grid()
plt.grid(axis='y', alpha=0.5, linestyle='--')
plt.xlabel("Período do dia", size=12)
plt.ylabel("Chuva em  mm³", size=12)
plt.xticks(x, (["Manhã", "Tarde", "Noite"]))
plt.bar(x, y, width=0.4, align='center', data=None, color="grey")
plt.show()
fig.savefig('grafico1.png')
plt.close(fig) #para cerrar la figura generada
# Out:
# /home/ejrueda/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# #### Gráfico 2

# %%
fig = plt.figure(figsize=(6,4))
plt.title("Os times que mais venceram o Campeonato Brasileiro da séria A", size=14)
x = range(5)
y = [9,8,7,6,5]
plt.axes().spines['right'].set_visible(False)
plt.axes().spines['top'].set_visible(False)
#colors = ['red', 'tan', 'brown',  'pink', 'green']
#plt.grid()
plt.xticks(x, (["Palmeiras", "Santos", "Corinthians", "São Paulo", "Flamengo"]))
plt.xlabel("Times", size=12)
plt.grid(axis='y', alpha=0.5, linestyle='--')
plt.ylabel("Quantidade de vitórias", size=12)
plt.bar(x, y, width=0.6, align='center', data=None,color="grey")
plt.show()
fig.savefig('grafico2.png')
plt.close(fig)
# Out:
# /home/ejrueda/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# #### Gráfico 3

# %%
fig = plt.figure(figsize=(6,4))
plt.title("Temperaturas máximas da última semana em Belém", size=14)
x = range(7)
y = [25.6,27.3,32.0,34.8,30.7,26.5,31.6]
plt.axes().spines['right'].set_visible(False)
plt.axes().spines['top'].set_visible(False)
#colors = ['red', 'tan', 'brown','black', 'pink', 'green', 'blue']
plt.grid(axis='y', alpha=0.5, linestyle='--')
plt.xticks(x, (["Domingo", "Segunda-feira", "Terça-feira", "Quarta-feira", "Quinta-feira", "Sexta-feira", "Sábado"]), rotation=15)
plt.xlabel("Días da semana", size=12)
plt.ylabel("Temperatura em °C", size=12)
plt.bar(x, y, width=0.6, align='center', data=None, color="grey")
plt.show()
fig.savefig('grafico3.png')
plt.close(fig)
# Out:
# /home/ejrueda/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# #### Gráfico 4

# %%
fig = plt.figure(figsize=(6,4))
plt.title("Top 9 escolas de samba com mais títulos no carnaval do RIo de Janeiro", size=14)
x = range(9)
y = [22,18,14,9,9,8,5,4,3]
plt.axes().spines['right'].set_visible(False)
plt.axes().spines['top'].set_visible(False)
#colors = ['tan', 'pink', 'red', 'brown','black', 'pink', 'green', 'blue', 'orange']
plt.grid(axis='y', alpha=0.5, linestyle='--')
#plt.yticks(y, y)
plt.xticks(x, (["Portela", "Mangueira", "Beija-Flor", "Salgueiro", "Império Serrano", "Imperatriz Leopoldinense",
                "Mocidade Independente", "Unidos da Tijuca", "Vila Isabel"]), rotation=30)
plt.xlabel("Escolas de Samba", size=12)
plt.ylabel("Quantidade de títulos", size=12)
plt.bar(x, y, width=0.6, align='center', data=None, color="grey")
plt.show()
fig.savefig('grafico4.png')
plt.close(fig)
# Out:
# /home/ejrueda/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
fig = plt.figure(figsize=(6,4))
plt.title("Top 9 escolas de samba com mais títulos no carnaval do RIo de Janeiro", size=14)
x = range(9)
y = [22,18,14,9,9,8,5,4,3]
plt.axes().spines['right'].set_visible(False)
plt.axes().spines['top'].set_visible(False)
#colors = ['tan', 'pink', 'red', 'brown','black', 'pink', 'green', 'blue', 'orange']
plt.grid(axis='y', alpha=0.5, linestyle='--')
plt.xticks(x, (["Portela", "Mangueira", "Beija-Flor", "Salgueiro", "Império Serrano", "Imperatriz Leopoldinense",
                "Mocidade Independente", "Unidos da Tijuca", "Vila Isabel"]), rotation=90)
plt.xlabel("Escolas de Samba", size=12)
plt.ylabel("Quantidade de títulos", size=12)
plt.bar(x, y, width=0.6, align='center', data=None, color="grey")
plt.show()
fig.savefig('grafico4_1.png')
plt.close(fig)
# Out:
# /home/ejrueda/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
