# %%
import pandas as pd
import numpy as np
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook, reset_output, curdoc
from bokeh.embed import file_html
from bokeh.models import LabelSet, Label, ColumnDataSource, FactorRange
from bokeh.transform import factor_cmap
import bokeh.plotting as bp
from bokeh.layouts import row, column
from bokeh.models.widgets import Slider, TextInput
from bokeh.transform import cumsum
from bokeh.palettes import Category10

# %%
data = pd.read_csv("./MC1/mc1-reports-data.csv",parse_dates=True,infer_datetime_format=True, index_col=0)
data = data.sort_index()
data = data.fillna(0)
data.to_csv("boxplot/data.csv")
data.head()
# Out:
#             sewer_and_water  power  roads_and_bridges  medical  buildings  \
# time
# 2020-04-06              2.0    4.0                1.0      0.0        4.0
# 2020-04-06              2.0    8.0                5.0      0.0        3.0
# 2020-04-06              9.0    7.0                5.0      0.0        4.0
# 2020-04-06             10.0    2.0                9.0      0.0       10.0
# 2020-04-06              6.0    2.0                9.0      0.0        4.0
#
#             shake_intensity  location
# time
# 2020-04-06              0.0        17
# 2020-04-06              0.0         2
# 2020-04-06              0.0         8
# 2020-04-06              0.0         4
# 2020-04-06              1.0        15

# %%
#data.loc[data.index.day==6].loc[data.loc[data.index.day==6].location==1].iloc[0,2:].values
data.loc[data.location==1].resample("5T", loffset="5T",).mean().ffill()
# Out:
#                      sewer_and_water  power  roads_and_bridges  medical  \
# time
# 2020-04-06 00:40:00              2.0   10.0                3.0      5.0
# 2020-04-06 00:45:00              2.0   10.0                3.0      5.0
# 2020-04-06 00:50:00              2.0   10.0                3.0      5.0
# 2020-04-06 00:55:00              2.0   10.0                3.0      5.0
# 2020-04-06 01:00:00              2.0   10.0                3.0      5.0
# 2020-04-06 01:05:00              2.0   10.0                3.0      5.0
# 2020-04-06 01:10:00              2.0   10.0                3.0      5.0
# 2020-04-06 01:15:00              2.0   10.0                3.0      5.0
# 2020-04-06 01:20:00              2.0   10.0                3.0      5.0
# 2020-04-06 01:25:00             10.0    7.0                6.0      7.0
# 2020-04-06 01:30:00              5.0    0.0                6.0      3.0
# 2020-04-06 01:35:00              5.0    0.0                6.0      3.0
# 2020-04-06 01:40:00              9.0   10.0                2.0      4.0
# 2020-04-06 01:45:00              9.0   10.0                2.0      4.0
# 2020-04-06 01:50:00              9.0   10.0                2.0      4.0
# 2020-04-06 01:55:00              9.0   10.0                2.0      4.0
# 2020-04-06 02:00:00              9.0   10.0                2.0      4.0
# 2020-04-06 02:05:00              6.0    1.0                0.0     10.0
# 2020-04-06 02:10:00              6.0    1.0                0.0     10.0
# 2020-04-06 02:15:00              6.0    1.0                0.0     10.0
# 2020-04-06 02:20:00              6.0    9.0                4.5      7.5
# 2020-04-06 02:25:00              3.0    0.0               10.0     10.0
# 2020-04-06 02:30:00              4.0    9.0                3.5      7.5
# 2020-04-06 02:35:00              5.0    0.0                4.0      4.0
# 2020-04-06 02:40:00              5.0    0.0                4.0      4.0
# 2020-04-06 02:45:00              5.0    0.0                4.0      4.0
# 2020-04-06 02:50:00              5.0    0.0                4.0      4.0
# 2020-04-06 02:55:00              5.0    0.0                4.0      4.0
# 2020-04-06 03:00:00              5.0    0.0                4.0      4.0
# 2020-04-10 22:20:00        2.0              0.0       1.0
# 2020-04-10 22:25:00        2.0              0.0       1.0
# 2020-04-10 22:30:00        2.0              0.0       1.0
# 2020-04-10 22:35:00        2.0              0.0       1.0
# 2020-04-10 22:40:00        1.0              1.0       1.0
# 2020-04-10 22:45:00        1.0              1.0       1.0
# 2020-04-10 22:50:00        1.0              1.0       1.0
# 2020-04-10 22:55:00        9.0              0.0       1.0
# 2020-04-10 23:00:00        9.0              0.0       1.0
# 2020-04-10 23:05:00        9.0              0.0       1.0
# 2020-04-10 23:10:00        9.0              0.0       1.0
# 2020-04-10 23:15:00        9.0              0.0       1.0
# 2020-04-10 23:20:00        9.0              0.0       1.0
# 2020-04-10 23:25:00        9.0              0.0       1.0
# 2020-04-10 23:30:00        9.0              0.0       1.0
# 2020-04-10 23:35:00        9.0              0.0       1.0
# 2020-04-10 23:40:00        9.0              0.0       1.0
# 2020-04-10 23:45:00        9.0              0.0       1.0
# 2020-04-10 23:50:00        9.0              0.0       1.0
# 2020-04-10 23:55:00        7.0              0.0       1.0
#
# [1432 rows x 7 columns]

# %% [markdown]
# #### Creación de los dataset
# - Se crea un dataset llamado "data_resample" para llevar el registro del cambio de los reportes de daño temporales, se le hace un "ressample" a los datos, ya que como son muchos el gráfico podría quedar lento para la interacción con el usuario.
#
# - Se crea otro dataset llamado "data_dist" para poder crear las distribuición de los datos a través del tiempo.

# %%
import datetime
datetime.date.fromtimestamp(1995142305)
# Out:
# datetime.date(2033, 3, 22)

# %%
import pandas as pd
import numpy as np
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook, reset_output, curdoc
from bokeh.embed import file_html
from bokeh.models import LabelSet, Label, ColumnDataSource, FactorRange, HoverTool
from bokeh.models.annotations import Title
from bokeh.transform import factor_cmap
import bokeh.plotting as bp
from bokeh.layouts import row, column,layout, gridplot
from bokeh.models.widgets import Slider, TextInput, RangeSlider, DateRangeSlider
from bokeh.transform import cumsum
from bokeh.palettes import Category10
import datetime

reset_output()
output_notebook()
#se cargan los datasets
data = pd.read_csv("timeplot/data.csv",parse_dates=True,infer_datetime_format=True, index_col=0)
p = figure(plot_height=400, plot_width=800, title="Reporte do danho no tempo",
           tools="box_select,pan,wheel_zoom,box_zoom,reset,save")

p2 = figure(plot_height=300, plot_width=300, title="Distribuição dos dados",
           tools="hover,box_select,pan,wheel_zoom,box_zoom,reset,save")

#Barras de interacción
s_day = Slider(title="registro de acordo com o dia", value=6.0, start=6.0, end=11.0, step=1.0)
s_vec= Slider(title="vecindario", value=1.0, start=1.0, end=19.0, step=1.0)
a = datetime.datetime(2020, 3, 22, hour=1, minute=2)
b = datetime.datetime(2020, 3, 26, hour=11, minute=2)
s_range = RangeSlider(title="intervalo de horas", start=0, end=24, value=(0,24), step=1)

data_aux = data.loc[data.index.day==6].loc[data.loc[data.index.day==6].location==1]
source = ColumnDataSource(dict(data_aux, x=data_aux.index))
fig_t1 = p.line(x="x", y="power", source=source)

#Para actualizar los datos con el cambio de los widgets
def update_data(attrname, old, new):
    #data_aux = data.loc[data.index.day==6].loc[data.loc[data.index.day==6].location==1]
    #source = ColumnDataSource(dict(data_aux, x=data_aux.index))
    return None

for w in [s_vec,s_day,s_range]:
    w.on_change('value', update_data)

# Set up layouts and add to document
inputs = column([s_vec,s_day,s_range], width=200)

curdoc().add_root(row(inputs, gridplot([[p, p2]]), width=400))

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4312">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="033aa681-c441-497d-b0af-7e1560b36169" data-root-id="4313"></div>

# %% [markdown]
# ### Gráfico interactivo
# - Se realiza el gráfico interactivo utlizando bokeh serve

# %%
import pandas as pd
import numpy as np
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook, reset_output, curdoc
from bokeh.embed import file_html
from bokeh.models import LabelSet, Label, ColumnDataSource, FactorRange, HoverTool
from bokeh.models.annotations import Title
from bokeh.transform import factor_cmap
import bokeh.plotting as bp
from bokeh.layouts import row, column,layout, gridplot
from bokeh.models.widgets import Slider, TextInput, RangeSlider
from bokeh.transform import cumsum
from bokeh.palettes import Category10

reset_output()
output_notebook()
#nombres de los vecindarios
#se cargan los datasets

p = figure(plot_height=400, plot_width=800, title="Reporte do danho no tempo",
           tools="box_select,pan,wheel_zoom,box_zoom,reset,save")

p2 = figure(plot_height=300, plot_width=300, title="Distribuição dos dados",
           tools="hover,box_select,pan,wheel_zoom,box_zoom,reset,save")

#Barras de interacción
s_day = Slider(title="registro de acordo com o dia", value=6.0, start=6.0, end=11.0, step=1.0)
s_vec= Slider(title="vecindario", value=1.0, start=1.0, end=19.0, step=1.0)
s_range = DateRangeSlider(title="Rango do dia", start=time(hour=4), end=110000, value=(10000, 50000), step=1000, format="0,0")

data_aux = data.loc[data.index.day==6].loc[data.loc[data.index.day==6].location==1]
source = ColumnDataSource(dict(data_aux, x=data_aux.index))
fig_t1 = p.line(x="x", y="power", source=source)

#Para actualizar los datos con el cambio de los widgets
def update_data(attrname, old, new):
    #data_aux = data.loc[data.index.day==6].loc[data.loc[data.index.day==6].location==1]
    #source = ColumnDataSource(dict(data_aux, x=data_aux.index))
    return None

for w in [s_day, s_vec]:
    w.on_change('value', update_data)

# Set up layouts and add to document
inputs = column([s_day,s_vec,s_range], width=200)

curdoc().add_root(row(inputs, gridplot([[p, p2]]), width=400))

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4784">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-09fcd4d110a7> in <module>()
#      27 s_day = Slider(title="registro de acordo com o dia", value=6.0, start=6.0, end=11.0, step=1.0)
#      28 s_vec= Slider(title="vecindario", value=1.0, start=1.0, end=19.0, step=1.0)
# ---> 29 s_range = DateRangeSlider(title="Rango do dia", start=time(hour=4), end=110000, value=(10000, 50000), step=1000, format="0,0")
#      30
#      31 data_aux = data.loc[data.index.day==6].loc[data.loc[data.index.day==6].location==1]
#
# ~/anaconda3/lib/python3.6/site-packages/bokeh/models/widgets/sliders.py in __init__(self, **kwargs)
#      60             if kwargs['start'] == kwargs['end']:
#      61                 raise ValueError("Slider 'start' and 'end' cannot be equal.")
# ---> 62         super(Widget, self).__init__(**kwargs)
#      63
#      64     title = String(default="", help="""
#
# ~/anaconda3/lib/python3.6/site-packages/bokeh/model.py in __init__(self, **kwargs)
#     305         kwargs.pop("id", None)
#     306
# --> 307         super(Model, self).__init__(**kwargs)
#     308         default_theme.apply_to_model(self)
#     309
#
# ~/anaconda3/lib/python3.6/site-packages/bokeh/core/has_props.py in __init__(self, **properties)
#     251
#     252         for name, value in properties.items():
# --> 253             setattr(self, name, value)
#     254
#     255     def __setattr__(self, name, value):
#
# ~/anaconda3/lib/python3.6/site-packages/bokeh/core/has_props.py in __setattr__(self, name, value)
#     278
#     279         if name in props or (descriptor is not None and descriptor.fset is not None):
# --> 280             super(HasProps, self).__setattr__(name, value)
#     281         else:
#     282             matches, text = difflib.get_close_matches(name.lower(), props), "similar"
#
# ~/anaconda3/lib/python3.6/site-packages/bokeh/core/property/descriptors.py in __set__(self, obj, value, setter)
#     543             raise RuntimeError("%s.%s is a readonly property" % (obj.__class__.__name__, self.name))
#     544
# --> 545         self._internal_set(obj, value, setter=setter)
#     546
#     547     def __delete__(self, obj):
#
# ~/anaconda3/lib/python3.6/site-packages/bokeh/core/property/descriptors.py in _internal_set(self, obj, value, hint, setter)
#     764
#     765         '''
# --> 766         value = self.property.prepare_value(obj, self.name, value)
#     767
#     768         old = self.__get__(obj, obj.__class__)
#
# ~/anaconda3/lib/python3.6/site-packages/bokeh/core/property/bases.py in prepare_value(self, obj_or_cls, name, value)
#     325                     break
#     326             else:
# --> 327                 raise e
#     328         else:
#     329             value = self.transform(value)
#
# ~/anaconda3/lib/python3.6/site-packages/bokeh/core/property/bases.py in prepare_value(self, obj_or_cls, name, value)
#     318         try:
#     319             if validation_on():
# --> 320                 self.validate(value)
#     321         except ValueError as e:
#     322             for tp, converter in self.alternatives:
#
# ~/anaconda3/lib/python3.6/site-packages/bokeh/core/property/datetime.py in validate(self, value, detail)
#      74         if not (value is None or isinstance(value, (datetime.date,) + string_types + (float,) + bokeh_integer_types)):
#      75             msg = "" if not detail else "expected a date, string or timestamp, got %r" % value
# ---> 76             raise ValueError(msg)
#      77
#      78 class Datetime(Property):
#
# ValueError: expected a date, string or timestamp, got datetime.time(4, 0)
